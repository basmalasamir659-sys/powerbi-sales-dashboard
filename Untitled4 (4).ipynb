# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv(r"/content/hotel_bookings.csv")

df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
df.shape
# Out:
# (119390, 32)

# %%
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
# Out:
# Rows: 119390
# Columns: 32

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 31994

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# company                           112593
# agent                              16340
# country                              488
# children                               4
# arrival_date_month                     0
# arrival_date_week_number               0
# hotel                                  0
# is_canceled                            0
# stays_in_weekend_nights                0
# arrival_date_day_of_month              0
# adults                                 0
# stays_in_week_nights                   0
# babies                                 0
# meal                                   0
# lead_time                              0
# arrival_date_year                      0
# distribution_channel                   0
# market_segment                         0
# previous_bookings_not_canceled         0
# is_repeated_guest                      0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# ...

# %%
df = df.drop_duplicates().copy()

print("New shape:", df.shape)
# Out:
# New shape: (87396, 32)

# %%
df['children'] = df['children'].fillna(0)

# %%
df['country'] = df['country'].fillna('Unknown')

# %%
df['agent'] = df['agent'].fillna(0)
df['company'] = df['company'].fillna(0)

# %%
numerical_cols = df.select_dtypes(include=np.number).columns.tolist()

categorical_cols = df.select_dtypes(
    include=["object", "category"]
).columns.tolist()

print("Numerical Columns:")
print(numerical_cols)

print("\nCategorical Columns:")
print(categorical_cols)
# Out:
# Numerical Columns:
# ['is_canceled', 'lead_time', 'arrival_date_year', 'arrival_date_week_number', 'arrival_date_day_of_month', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'is_repeated_guest', 'previous_cancellations', 'previous_bookings_not_canceled', 'booking_changes', 'agent', 'company', 'days_in_waiting_list', 'adr', 'required_car_parking_spaces', 'total_of_special_requests']
#
# Categorical Columns:
# ['hotel', 'arrival_date_month', 'meal', 'country', 'market_segment', 'distribution_channel', 'reserved_room_type', 'assigned_room_type', 'deposit_type', 'customer_type', 'reservation_status', 'reservation_status_date']

# %%
df['total_nights'] = (
    df['stays_in_weekend_nights'] +
    df['stays_in_week_nights']
)

# %%
df['total_guests'] = (
    df['adults'] +
    df['children'] +
    df['babies']
)

# %%
df.nunique()
# Out:
# hotel                                2
# is_canceled                          2
# lead_time                          479
# arrival_date_year                    3
# arrival_date_month                  12
# arrival_date_week_number            53
# arrival_date_day_of_month           31
# stays_in_weekend_nights             17
# stays_in_week_nights                35
# adults                              14
# children                             5
# babies                               5
# meal                                 5
# country                            178
# market_segment                       8
# distribution_channel                 5
# is_repeated_guest                    2
# previous_cancellations              15
# previous_bookings_not_canceled      73
# reserved_room_type                  10
# assigned_room_type                  12
# booking_changes                     21
# deposit_type                         3
# agent                              334
# ...

# %%
df['estimated_revenue'] = df['adr'] * df['total_nights']

# %%
missing_percentage = (df.isna().sum() / len(df)) * 100

missing_percentage[missing_percentage > 0].sort_values(
    ascending=False
)
# Out:
# Series([], dtype: float64)

# %%
df['realized_revenue'] = np.where(
    df['is_canceled'] == 0,
    df['estimated_revenue'],
    0
)

# %%
df["reservation_status_date"] = pd.to_datetime(
    df["reservation_status_date"],
    errors="coerce"
)

df["year"] = df["reservation_status_date"].dt.year

df["month"] = df["reservation_status_date"].dt.month

df["month_name"] = df["reservation_status_date"].dt.month_name()

df["day"] = df["reservation_status_date"].dt.day

df["day_of_week"] = df["reservation_status_date"].dt.day_name()

# %%
df[[
    "reservation_status_date",
    "year",
    "month",
    "month_name",
    "day_of_week"
]].head()
# Out:
#   reservation_status_date  year  month month_name day_of_week
# 0              2015-07-01  2015      7       July   Wednesday
# 1              2015-07-01  2015      7       July   Wednesday
# 2              2015-07-02  2015      7       July    Thursday
# 3              2015-07-02  2015      7       July    Thursday
# 4              2015-07-03  2015      7       July      Friday

# %%
hotel_counts = df['hotel'].value_counts()

plt.figure(figsize=(8,5))
sns.barplot(x=hotel_counts.index, y=hotel_counts.values)

plt.title('Bookings by Hotel')
plt.xlabel('Hotel')
plt.ylabel('Number of Bookings')
plt.show()

# %%
plt.figure(figsize=(8,5))

sns.countplot(
    data=df,
    x='hotel',
    hue='is_canceled'
)

plt.title('Cancellation Status by Hotel')
plt.xlabel('Hotel')
plt.ylabel('Bookings')
plt.show()

# %%
cancellation_rate = (
    df.groupby('hotel')['is_canceled']
    .mean()
    .mul(100)
)

plt.figure(figsize=(8,5))

sns.barplot(
    x=cancellation_rate.index,
    y=cancellation_rate.values
)

plt.title('Cancellation Rate by Hotel')
plt.xlabel('Hotel')
plt.ylabel('Cancellation Rate (%)')
plt.show()

# %%
segment_cancel = (
    df.groupby('market_segment')['is_canceled']
    .mean()
    .mul(100)
    .sort_values(ascending=False)
)

plt.figure(figsize=(10,5))

sns.barplot(
    x=segment_cancel.index,
    y=segment_cancel.values
)

plt.xticks(rotation=45)
plt.title('Cancellation Rate by Market Segment')
plt.xlabel('Market Segment')
plt.ylabel('Cancellation Rate (%)')
plt.show()

# %%
deposit_cancel = (
    df.groupby('deposit_type')['is_canceled']
    .mean()
    .mul(100)
    .sort_values(ascending=False)
)

plt.figure(figsize=(8,5))

sns.barplot(
    x=deposit_cancel.index,
    y=deposit_cancel.values
)

plt.title('Cancellation Rate by Deposit Type')
plt.xlabel('Deposit Type')
plt.ylabel('Cancellation Rate (%)')
plt.show()

# %%
monthly_bookings = (
    df.groupby('arrival_date_month')
    .size()
    .reindex(months.keys())
)

plt.figure(figsize=(12,5))

sns.lineplot(
    x=monthly_bookings.index,
    y=monthly_bookings.values,
    marker='o'
)

plt.xticks(rotation=45)
plt.title('Bookings by Month')
plt.xlabel('Month')
plt.ylabel('Number of Bookings')
plt.show()

# %%
monthly_cancel = (
    df.groupby('arrival_date_month')['is_canceled']
    .mean()
    .mul(100)
    .reindex(months.keys())
)

plt.figure(figsize=(12,5))

sns.lineplot(
    x=monthly_cancel.index,
    y=monthly_cancel.values,
    marker='o'
)

plt.xticks(rotation=45)
plt.title('Cancellation Rate by Month')
plt.xlabel('Month')
plt.ylabel('Cancellation Rate (%)')
plt.show()

# %%
adr_hotel = df.groupby('hotel')['adr'].mean()

plt.figure(figsize=(8,5))

sns.barplot(
    x=adr_hotel.index,
    y=adr_hotel.values
)

plt.title('Average Daily Rate by Hotel')
plt.xlabel('Hotel')
plt.ylabel('ADR')
plt.show()

# %%
monthly_adr = (
    df.groupby('arrival_date_month')['adr']
    .mean()
    .reindex(months.keys())
)

plt.figure(figsize=(12,5))

sns.lineplot(
    x=monthly_adr.index,
    y=monthly_adr.values,
    marker='o'
)

plt.xticks(rotation=45)
plt.title('Average ADR by Month')
plt.xlabel('Month')
plt.ylabel('ADR')
plt.show()

# %%
segment_counts = df['market_segment'].value_counts()

plt.figure(figsize=(10,5))

sns.barplot(
    x=segment_counts.index,
    y=segment_counts.values
)

plt.xticks(rotation=45)
plt.title('Bookings by Market Segment')
plt.xlabel('Market Segment')
plt.ylabel('Bookings')
plt.show()

# %%
plt.figure(figsize=(12,6))

sns.countplot(
    data=df,
    x='market_segment',
    hue='hotel'
)

plt.xticks(rotation=45)
plt.title('Bookings by Market Segment and Hotel')
plt.xlabel('Market Segment')
plt.ylabel('Bookings')
plt.show()

# %%
plt.figure(figsize=(10,5))

sns.histplot(
    data=df,
    x='lead_time',
    bins=50,
    kde=True
)

plt.title('Distribution of Lead Time')
plt.xlabel('Lead Time (Days)')
plt.ylabel('Number of Bookings')
plt.show()

# %%
plt.figure(figsize=(10,6))

sns.boxplot(
    data=df,
    x='is_canceled',
    y='lead_time'
)

plt.title('Lead Time vs Cancellation')
plt.xlabel('Cancellation Status')
plt.ylabel('Lead Time')
plt.show()

# %%
plt.figure(figsize=(10,6))

sns.scatterplot(
    data=df.sample(10000, random_state=42),
    x='lead_time',
    y='adr',
    hue='hotel',
    alpha=0.5
)

plt.title('Lead Time vs ADR')
plt.xlabel('Lead Time')
plt.ylabel('ADR')
plt.show()

# %%
plt.figure(figsize=(10,6))

sns.scatterplot(
    data=df.sample(10000, random_state=42),
    x='total_nights',
    y='adr',
    hue='hotel',
    alpha=0.5
)

plt.title('Stay Length vs ADR')
plt.xlabel('Total Nights')
plt.ylabel('ADR')
plt.show()

# %%
room_counts = df['reserved_room_type'].value_counts()

plt.figure(figsize=(10,5))

sns.barplot(
    x=room_counts.index,
    y=room_counts.values
)

plt.title('Bookings by Reserved Room Type')
plt.xlabel('Reserved Room Type')
plt.ylabel('Bookings')
plt.show()

# %%
room_match = (
    df['reserved_room_type'] ==
    df['assigned_room_type']
)

room_match_counts = room_match.value_counts()

plt.figure(figsize=(7,5))

sns.barplot(
    x=['Same Room Type', 'Different Room Type'],
    y=room_match_counts.values
)

plt.title('Reserved Room vs Assigned Room')
plt.ylabel('Bookings')
plt.show()

# %%
plt.figure(figsize=(12,6))

scatter = plt.scatter(
    df['lead_time'],
    df['adr'],
    c=df['is_canceled']
)

plt.colorbar(scatter, label='Cancellation')

plt.title('Lead Time vs ADR Colored by Cancellation')
plt.xlabel('Lead Time')
plt.ylabel('ADR')

plt.show()

# %%
cols = ['lead_time', 'adr', 'stays_in_week_nights']

sns.pairplot(df[cols], palette='Set1')

plt.show()
# Out:
# /usr/local/lib/python3.13/dist-packages/seaborn/axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# /usr/local/lib/python3.13/dist-packages/seaborn/axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# /usr/local/lib/python3.13/dist-packages/seaborn/axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# /usr/local/lib/python3.13/dist-packages/seaborn/axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# /usr/local/lib/python3.13/dist-packages/seaborn/axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# ...

# %%
customer_counts = df['customer_type'].value_counts()

plt.figure(figsize=(10,5))

sns.barplot(
    x=customer_counts.index,
    y=customer_counts.values
)

plt.title('Bookings by Customer Type')
plt.xlabel('Customer Type')
plt.ylabel('Bookings')
plt.show()

# %%
plt.figure(figsize=(15,8))

hotel_counts = df['hotel'].value_counts()

hotel_counts.plot(
    kind='pie',
    autopct='%1.1f%%',
    title='Hotel Type Distribution',
    cmap='Set3',
    legend=True
)

plt.ylabel("")
plt.show()

# %%
repeat_counts = df['is_repeated_guest'].value_counts()

plt.figure(figsize=(7,5))

sns.barplot(
    x=['New Guest', 'Repeated Guest'],
    y=repeat_counts.values
)

plt.title('New vs Repeated Guests')
plt.ylabel('Bookings')
plt.show()

# %%
request_cancel = (
    df.groupby('total_of_special_requests')['is_canceled']
    .mean()
    .mul(100)
)

plt.figure(figsize=(9,5))

sns.barplot(
    x=request_cancel.index,
    y=request_cancel.values
)

plt.title('Cancellation Rate vs Special Requests')
plt.xlabel('Number of Special Requests')
plt.ylabel('Cancellation Rate (%)')
plt.show()

# %%
plt.figure(figsize=(10,6))

sns.scatterplot(
    data=df.sample(10000, random_state=42),
    x='days_in_waiting_list',
    y='lead_time',
    hue='is_canceled',
    alpha=0.5
)

plt.title('Waiting List vs Lead Time by Cancellation')
plt.xlabel('Days in Waiting List')
plt.ylabel('Lead Time')
plt.show()

# %%
meal_counts = df['meal'].value_counts()

plt.figure(figsize=(8,5))

sns.barplot(
    x=meal_counts.index,
    y=meal_counts.values
)

plt.title('Bookings by Meal Type')
plt.xlabel('Meal')
plt.ylabel('Bookings')
plt.show()

# %%
plt.figure(figsize=(10,6))

sns.countplot(
    data=df,
    x='meal',
    hue='hotel'
)

plt.title('Meal Preferences by Hotel')
plt.xlabel('Meal')
plt.ylabel('Bookings')
plt.show()

# %%
segment_price = df.groupby('market_segment')['adr'].mean().sort_values(ascending=False)

plt.figure(figsize=(12,6))

sns.barplot(x=segment_price.index, y=segment_price.values, palette='Spectral')

plt.title('Average ADR by Market Segment')

plt.xlabel("Market Segment")
plt.ylabel("Average ADR")

plt.show()
# Out:
# /tmp/ipykernel_7728/3713684459.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=segment_price.index, y=segment_price.values, palette='Spectral')

# %%
channel_counts = df['distribution_channel'].value_counts()

plt.figure(figsize=(10,5))

sns.barplot(
    x=channel_counts.index,
    y=channel_counts.values
)

plt.title('Bookings by Distribution Channel')
plt.xlabel('Distribution Channel')
plt.ylabel('Bookings')
plt.show()

# %%
parking = df['required_car_parking_spaces'].value_counts().sort_index()

plt.figure(figsize=(9,5))

sns.barplot(
    x=parking.index,
    y=parking.values
)

plt.title('Required Car Parking Spaces')
plt.xlabel('Parking Spaces')
plt.ylabel('Bookings')
plt.show()

# %%
plt.figure(figsize=(10,5))

sns.histplot(
    data=df[df['total_nights'] <= 20],
    x='total_nights',
    bins=20
)

plt.title('Distribution of Total Stay Length')
plt.xlabel('Total Nights')
plt.ylabel('Bookings')
plt.show()

# %%
plt.figure(figsize=(10,6))

sns.boxplot(
    data=df[df['total_nights'] <= 15],
    x='hotel',
    y='total_nights'
)

plt.title('Stay Length by Hotel')
plt.xlabel('Hotel')
plt.ylabel('Total Nights')
plt.show()

# %%
numeric_cols = [
    'is_canceled',
    'lead_time',
    'stays_in_weekend_nights',
    'stays_in_week_nights',
    'adults',
    'children',
    'babies',
    'previous_cancellations',
    'previous_bookings_not_canceled',
    'booking_changes',
    'days_in_waiting_list',
    'adr',
    'required_car_parking_spaces',
    'total_of_special_requests',
    'total_nights',
    'total_guests'
]

corr = df[numeric_cols].corr()

plt.figure(figsize=(14,10))

sns.heatmap(
    corr,
    annot=True,
    fmt='.2f',
    cmap='coolwarm'
)

plt.title('Correlation Heatmap')
plt.show()

# %%
top_country_names = df['country'].value_counts().head(10).index

country_cancel = (
    df[df['country'].isin(top_country_names)]
    .groupby('country')['is_canceled']
    .mean()
    .mul(100)
    .sort_values(ascending=False)
)

plt.figure(figsize=(10,6))

sns.barplot(
    x=country_cancel.values,
    y=country_cancel.index
)

plt.title('Cancellation Rate of Top 10 Countries')
plt.xlabel('Cancellation Rate (%)')
plt.ylabel('Country')
plt.show()

# %%
plt.figure(figsize=(10,8))

hotel_count = df['hotel'].value_counts()

hotel_count.plot(
    kind='pie',
    title='Hotel Type Distribution',
    autopct='%1.1f%%',
    cmap='Set3'
)

plt.ylabel('')
plt.show()

# %%
hotel_month_cancel = (
    df.groupby(['arrival_date_month', 'hotel'])['is_canceled']
    .mean()
    .mul(100)
    .reset_index()
)

hotel_month_cancel['arrival_date_month'] = pd.Categorical(
    hotel_month_cancel['arrival_date_month'],
    categories=months.keys(),
    ordered=True
)

plt.figure(figsize=(14,6))

sns.lineplot(
    data=hotel_month_cancel,
    x='arrival_date_month',
    y='is_canceled',
    hue='hotel',
    marker='o'
)

plt.title('Cancellation Rate by Month and Hotel')
plt.xlabel('Month')
plt.ylabel('Cancellation Rate (%)')
plt.xticks(rotation=45)
plt.show()

# %%
hotel_month_adr = (
    df.groupby(['arrival_date_month', 'hotel'])['adr']
    .mean()
    .reset_index()
)

hotel_month_adr['arrival_date_month'] = pd.Categorical(
    hotel_month_adr['arrival_date_month'],
    categories=months.keys(),
    ordered=True
)

plt.figure(figsize=(14,6))

sns.lineplot(
    data=hotel_month_adr,
    x='arrival_date_month',
    y='adr',
    hue='hotel',
    marker='o'
)

plt.title('ADR by Month and Hotel')
plt.xlabel('Month')
plt.ylabel('ADR')
plt.xticks(rotation=45)
plt.show()

# %%
segment_hotel_cancel = (
    df.groupby(['hotel', 'market_segment'])['is_canceled']
    .mean()
    .mul(100)
    .reset_index()
)

plt.figure(figsize=(13,6))

sns.barplot(
    data=segment_hotel_cancel,
    x='market_segment',
    y='is_canceled',
    hue='hotel'
)

plt.title('Cancellation Rate by Market Segment and Hotel')
plt.xlabel('Market Segment')
plt.ylabel('Cancellation Rate (%)')
plt.xticks(rotation=45)
plt.show()

# %%
revenue_hotel = (
    df.groupby('hotel')['realized_revenue']
    .sum()
)

plt.figure(figsize=(8,5))

sns.barplot(
    x=revenue_hotel.index,
    y=revenue_hotel.values
)

plt.title('Estimated Realized Revenue by Hotel')
plt.xlabel('Hotel')
plt.ylabel('Revenue')
plt.show()

# %%
monthly_revenue = (
    df.groupby('arrival_date_month')['realized_revenue']
    .sum()
    .reindex(months.keys())
)

plt.figure(figsize=(12,5))

sns.lineplot(
    x=monthly_revenue.index,
    y=monthly_revenue.values,
    marker='o'
)

plt.title('Estimated Realized Revenue by Month')
plt.xlabel('Month')
plt.ylabel('Revenue')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))

sns.histplot(data=df, x="adr", bins=40, kde=True)

plt.title("Distribution of Average Daily Rate (ADR)")
plt.xlabel("ADR")
plt.ylabel("Frequency")

plt.show()

# %%
plt.figure(figsize=(15,7))

sns.boxplot(data=df, x='hotel', y='adr')

plt.title("Distribution of ADR by Hotel")
plt.xlabel("Hotel")
plt.ylabel("ADR")

plt.show()

# %%
summary = pd.DataFrame({
    'Metric': [
        'Total Bookings',
        'Total Cancellations',
        'Cancellation Rate',
        'Average ADR',
        'Average Lead Time',
        'Average Stay Length',
        'Total Estimated Revenue'
    ],

    'Value': [
        len(df),
        df['is_canceled'].sum(),
        df['is_canceled'].mean() * 100,
        df['adr'].mean(),
        df['lead_time'].mean(),
        df['total_nights'].mean(),
        df['realized_revenue'].sum()
    ]
})

summary
# Out:
#                     Metric         Value
# 0           Total Bookings  8.739600e+04
# 1      Total Cancellations  2.402500e+04
# 2        Cancellation Rate  2.748982e+01
# 3              Average ADR  1.063372e+02
# 4        Average Lead Time  7.989137e+01
# 5      Average Stay Length  3.630658e+00
# 6  Total Estimated Revenue  2.297690e+07
